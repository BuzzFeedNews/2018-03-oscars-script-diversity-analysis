# %% [markdown]
# # Caculating descriptive statistics by film and by year

# %%
import pandas as pd
import os
from glob import glob
import numpy as np

# %% [markdown]
# ### Load the data

# %%
actors = pd.read_csv("../data/actor-metrics.csv")
actors.head()
# Out:
#    year                        film             actor  characters  \
# 0  1989  born-on-the-fourth-of-july          Dale Dye     COLONEL
# 1  1989  born-on-the-fourth-of-july  David Warshofsky  LIEUTENANT
# 2  1989  born-on-the-fourth-of-july      Frank Whaley       TIMMY
# 3  1989  born-on-the-fourth-of-july      Jerry Levine       STEVE
# 4  1989  born-on-the-fourth-of-july   John F. Kennedy     KENNEDY
#
#                                   imdb gender             race race_simple  \
# 0  http://www.imdb.com/name/nm0245653/   male  White/Caucasian       White
# 1  http://www.imdb.com/name/nm0913175/   male  White/Caucasian       White
# 2  http://www.imdb.com/name/nm0001844/   male  White/Caucasian       White
# 3  http://www.imdb.com/name/nm0505842/   male  White/Caucasian       White
# 4                                  NaN   male  White/Caucasian       White
#
#    words  sentences
# 0  216.0       15.0
# 1  290.0       40.0
# 2  104.0       14.0
# 3  300.0       35.0
# 4  217.0        5.0

# %% [markdown]
# ### Define some analysis functions

# %%
def single_group(col):
    """
    Groups on one col 
    Sums sentences and words
    Calcs percents of columns against whole
    Returns data frame
    """
    return actors.groupby(col).agg({
        "sentences": np.sum, # sum number of sentences
        "words": np.sum, # sum number of words
        "actor": "count"
    }).assign(
        percent_sentences = lambda frame: ( frame['sentences'] / frame['sentences'].sum() ) * 100,
        percent_words = lambda frame: ( frame['words'] / frame['words'].sum()) * 100,
        percent_actor = lambda frame: ( 
            (frame["actor"] / frame['actor'].sum()) * 100
        ) 
    )

# %%
def double_group(col1, col2):
    """
    Groups on two cols 
    Counts actors and percent for race or gender 
    Calcs percents of columns against whole
    Returns data frame
    """
    
    grouped = actors.groupby([col1, col2]).agg({
        "actor": "count"
        # unstack to remove multindex
    }).unstack() \
    .fillna(0).astype(int)

    # drop the extra multi column
    grouped.columns = grouped.columns.get_level_values(1)

    # create new col for total
    if col2 == "gender":
        grouped['total'] = grouped['male'] + grouped['female']
        # make percent cols
        grouped['female_percent'] = (grouped['female'] / grouped['total'] ) * 100
        grouped['male_percent'] = ( grouped['male'] / grouped['total']) * 100
    elif col2 == "race_simple":
        # make a total column
        grouped['total'] = grouped['POC'] + grouped['White']
        # make a percent column
        grouped['white_percent'] = (grouped['White'] / grouped['total'] ) * 100
        grouped['poc_percent'] = ( grouped['POC'] / grouped['total']) * 100

    # remove the column's namne
    grouped.columns.name = ""

    # display
    return grouped

# %%
def double_word_group(unit, col1, col2):
    """
    Takes words/sentences as "unit" and two arbitrary columns
    """
    # group by year and gender
    bycols = actors.groupby([col1, col2]).agg({
        unit: np.sum,
    }).unstack() \
    .fillna(0).astype(int)
    # drop the extra multi column
    bycols.columns = bycols.columns.droplevel()

    # math:
    if col2 == "gender":
        bycols['total_{}'.format(unit)] = bycols['female'] + bycols['male']

        # make a percent column
        bycols['female_percent'] = (bycols['female'] / bycols['total_{0}'.format(unit)] ) * 100
        bycols['male_percent'] = ( bycols['male'] / bycols['total_{0}'.format(unit)]) * 100
    elif col2 == "race_simple":
        
        bycols['total_{0}'.format(unit)] = bycols['POC'] + bycols['White']

        # make a percent column
        bycols['white_percent'] = (bycols['White'] / bycols['total_{0}'.format(unit)] ) * 100
        bycols['poc_percent'] = ( bycols['POC'] / bycols['total_{0}'.format(unit)]) * 100
        
    # clean up the column
    bycols.columns.name = ""

    # display last three columns for clarity
    return bycols.iloc[:, 2:]

# %% [markdown]
# ### Calculate the statistics
#
# ** Casting by gender across all films, all years **

# %%
single_group('gender')
# Out:
#         sentences     words  actor  percent_sentences  percent_words  \
# gender
# female     8114.0   51119.0     84             30.792      29.607942
# male      18237.0  121534.0    181             69.208      70.392058
#
#         percent_actor
# gender
# female      31.698113
# male        68.301887

# %% [markdown]
# ** Casting by race across all films, all years **

# %%
single_group('race')
# Out:
#                         sentences     words  actor  percent_sentences  \
# race
# 2+ Race                     252.0    1621.0      9           0.956320
# Asian                        81.0     667.0      3           0.307389
# Black/African American     1915.0   12031.0     15           7.267276
# Hispanic/Latino             129.0     853.0      3           0.489545
# White/Caucasian           23974.0  157481.0    235          90.979469
#
#                         percent_words  percent_actor
# race
# 2+ Race                      0.938877       3.396226
# Asian                        0.386324       1.132075
# Black/African American       6.968312       5.660377
# Hispanic/Latino              0.494055       1.132075
# White/Caucasian             91.212432      88.679245

# %% [markdown]
# **Casting by simplified race across all films, all years**

# %%
single_group('race_simple')
# Out:
#              sentences     words  actor  percent_sentences  percent_words  \
# race_simple
# POC             2377.0   15172.0     30           9.020531       8.787568
# White          23974.0  157481.0    235          90.979469      91.212432
#
#              percent_actor
# race_simple
# POC              11.320755
# White            88.679245

# %% [markdown]
# ** Casting by gender and year **

# %%
double_group('year', 'gender')
# Out:
#       female  male  total  female_percent  male_percent
# year
# 1989      12    37     49       24.489796     75.510204
# 2015      40    77    117       34.188034     65.811966
# 2017      32    67     99       32.323232     67.676768

# %% [markdown]
# ** Casting by race and year **

# %%
double_group('year', 'race_simple')
# Out:
#       POC  White  total  white_percent  poc_percent
# year
# 1989    4     45     49      91.836735     8.163265
# 2015   13    104    117      88.888889    11.111111
# 2017   13     86     99      86.868687    13.131313

# %% [markdown]
# ** Number of sentences by gender by year **

# %%
double_word_group('sentences', 'year', 'gender')
# Out:
#       total_sentences  female_percent  male_percent
# year
# 1989             5708       27.014716     72.985284
# 2015            10741       30.676846     69.323154
# 2017             9902       33.094324     66.905676

# %% [markdown]
# ** Number of words by year and gender **

# %%
double_word_group('words', 'year', 'gender')
# Out:
#       total_words  female_percent  male_percent
# year
# 1989        33725       26.407709     73.592291
# 2015        72918       27.956060     72.043940
# 2017        66010       33.067717     66.932283

# %% [markdown]
# ** Number of sentences by race and year **

# %%
double_word_group('sentences', 'year', 'race_simple')
# Out:
#       total_sentences  white_percent  poc_percent
# year
# 1989             5708      86.580238    13.419762
# 2015            10741      94.488409     5.511591
# 2017             9902      89.709150    10.290850

# %% [markdown]
# ** Number of words by race and year **

# %%
double_word_group('words', 'year', 'race_simple')
# Out:
#       total_words  white_percent  poc_percent
# year
# 1989        33725      84.853966    15.146034
# 2015        72918      94.459530     5.540470
# 2017        66010      90.874110     9.125890

# %% [markdown]
# ** Casting by race and film **

# %%
double_group('film', 'race_simple').sort_values("poc_percent", ascending = False)
# Out:
#                                           POC  White  total  white_percent  \
# film
# get-out                                     5      6     11      54.545455
# the-martian                                 5      9     14      64.285714
# driving-miss-daisy                          2      4      6      66.666667
# room                                        3      9     12      75.000000
# mad-max                                     2     10     12      83.333333
# lady-bird                                   2     10     12      83.333333
# three-billboards-outside-ebbing-missouri    3     15     18      83.333333
# the-big-short                               3     20     23      86.956522
# field-of-dreams                             1      7      8      87.500000
# darkest-hour                                1     10     11      90.909091
# the-shape-of-water                          1     10     11      90.909091
# born-on-the-fourth-of-july                  1     14     15      93.333333
# the-post                                    1     15     16      93.750000
# dunkirk                                     0     10     10     100.000000
# dead-poets-society                          0     11     11     100.000000
# bridge-of-spies                             0     17     17     100.000000
# my-left-foot                                0      9      9     100.000000
# phantom-thread                              0      4      4     100.000000
# call-me-by-your-name                        0      6      6     100.000000
# spotlight                                   0     15     15     100.000000
# brooklyn                                    0     18     18     100.000000
# the-revenant                                0      6      6     100.000000
#
#                                           poc_percent
# film
# get-out                                     45.454545
# the-martian                                 35.714286
# driving-miss-daisy                          33.333333
# room                                        25.000000
# mad-max                                     16.666667
# lady-bird                                   16.666667
# three-billboards-outside-ebbing-missouri    16.666667
# the-big-short                               13.043478
# field-of-dreams                             12.500000
# darkest-hour                                 9.090909
# the-shape-of-water                           9.090909
# born-on-the-fourth-of-july                   6.666667
# the-post                                     6.250000
# dunkirk                                      0.000000
# dead-poets-society                           0.000000
# bridge-of-spies                              0.000000
# my-left-foot                                 0.000000
# phantom-thread                               0.000000
# call-me-by-your-name                         0.000000
# spotlight                                    0.000000
# brooklyn                                     0.000000
# the-revenant                                 0.000000

# %% [markdown]
# ** Casting by gender and film **

# %%
double_group('film', 'gender').sort_values(
    "female_percent", ascending = False
)
# Out:
#                                           female  male  total  female_percent  \
# film
# mad-max                                        9     3     12       75.000000
# brooklyn                                      13     5     18       72.222222
# lady-bird                                      7     5     12       58.333333
# call-me-by-your-name                           3     3      6       50.000000
# room                                           6     6     12       50.000000
# phantom-thread                                 2     2      4       50.000000
# driving-miss-daisy                             3     3      6       50.000000
# three-billboards-outside-ebbing-missouri       7    11     18       38.888889
# field-of-dreams                                3     5      8       37.500000
# get-out                                        4     7     11       36.363636
# my-left-foot                                   3     6      9       33.333333
# the-post                                       5    11     16       31.250000
# the-martian                                    4    10     14       28.571429
# the-big-short                                  6    17     23       26.086957
# darkest-hour                                   2     9     11       18.181818
# the-shape-of-water                             2     9     11       18.181818
# born-on-the-fourth-of-july                     2    13     15       13.333333
# dead-poets-society                             1    10     11        9.090909
# spotlight                                      1    14     15        6.666667
# bridge-of-spies                                1    16     17        5.882353
# dunkirk                                        0    10     10        0.000000
# the-revenant                                   0     6      6        0.000000
#
#                                           male_percent
# film
# mad-max                                      25.000000
# brooklyn                                     27.777778
# lady-bird                                    41.666667
# call-me-by-your-name                         50.000000
# room                                         50.000000
# phantom-thread                               50.000000
# driving-miss-daisy                           50.000000
# three-billboards-outside-ebbing-missouri     61.111111
# field-of-dreams                              62.500000
# get-out                                      63.636364
# my-left-foot                                 66.666667
# the-post                                     68.750000
# the-martian                                  71.428571
# the-big-short                                73.913043
# darkest-hour                                 81.818182
# the-shape-of-water                           81.818182
# born-on-the-fourth-of-july                   86.666667
# dead-poets-society                           90.909091
# spotlight                                    93.333333
# bridge-of-spies                              94.117647
# dunkirk                                     100.000000
# the-revenant                                100.000000

# %% [markdown]
# ** Number of words by gender and film **

# %%
double_word_group("words", "film", "gender").sort_values(
    by = "female_percent",
    ascending = False
)
# Out:
#                                           total_words  female_percent  \
# film
# lady-bird                                        7664       77.622651
# mad-max                                          3130       73.993610
# brooklyn                                        10591       70.125578
# room                                             8373       62.617939
# phantom-thread                                   5541       49.503700
# my-left-foot                                     4749       45.441146
# driving-miss-daisy                               9675       42.821705
# three-billboards-outside-ebbing-missouri         9480       35.896624
# the-post                                        11135       35.671307
# get-out                                          7094       28.742599
# the-martian                                     10550       23.582938
# call-me-by-your-name                             6673       20.725311
# field-of-dreams                                  8933       20.687339
# the-shape-of-water                               8036       18.292683
# darkest-hour                                     8034       10.816530
# born-on-the-fourth-of-july                       5151       10.405746
# spotlight                                       13113       10.203615
# the-big-short                                   13241        9.772676
# dead-poets-society                               5217        4.236151
# bridge-of-spies                                  9915        2.813918
# dunkirk                                          2353        0.000000
# the-revenant                                     4005        0.000000
#
#                                           male_percent
# film
# lady-bird                                    22.377349
# mad-max                                      26.006390
# brooklyn                                     29.874422
# room                                         37.382061
# phantom-thread                               50.496300
# my-left-foot                                 54.558854
# driving-miss-daisy                           57.178295
# three-billboards-outside-ebbing-missouri     64.103376
# the-post                                     64.328693
# get-out                                      71.257401
# the-martian                                  76.417062
# call-me-by-your-name                         79.274689
# field-of-dreams                              79.312661
# the-shape-of-water                           81.707317
# darkest-hour                                 89.183470
# born-on-the-fourth-of-july                   89.594254
# spotlight                                    89.796385
# the-big-short                                90.227324
# dead-poets-society                           95.763849
# bridge-of-spies                              97.186082
# dunkirk                                     100.000000
# the-revenant                                100.000000

# %% [markdown]
# **Number of sentences by gender and film**

# %%
double_word_group("sentences", "film", "gender").sort_values(
    by = "female_percent",
    ascending = False
)
# Out:
#                                           total_sentences  female_percent  \
# film
# lady-bird                                            1148       78.310105
# brooklyn                                             1469       73.315180
# mad-max                                               694       72.766571
# room                                                 1414       61.386139
# phantom-thread                                        783       47.509579
# my-left-foot                                          980       44.795918
# driving-miss-daisy                                   1520       44.342105
# three-billboards-outside-ebbing-missouri             1195       37.154812
# the-post                                             1528       36.060209
# get-out                                              1330       31.954887
# the-martian                                          1507       27.803583
# field-of-dreams                                      1299       21.939954
# call-me-by-your-name                                 1048       21.564885
# the-shape-of-water                                   1347       16.852264
# darkest-hour                                         1077       12.349118
# born-on-the-fourth-of-july                            620       12.096774
# spotlight                                            1975       10.582278
# the-big-short                                        1782        9.876543
# dead-poets-society                                   1289        5.352987
# bridge-of-spies                                      1351        3.034789
# dunkirk                                               446        0.000000
# the-revenant                                          549        0.000000
#
#                                           male_percent
# film
# lady-bird                                    21.689895
# brooklyn                                     26.684820
# mad-max                                      27.233429
# room                                         38.613861
# phantom-thread                               52.490421
# my-left-foot                                 55.204082
# driving-miss-daisy                           55.657895
# three-billboards-outside-ebbing-missouri     62.845188
# the-post                                     63.939791
# get-out                                      68.045113
# the-martian                                  72.196417
# field-of-dreams                              78.060046
# call-me-by-your-name                         78.435115
# the-shape-of-water                           83.147736
# darkest-hour                                 87.650882
# born-on-the-fourth-of-july                   87.903226
# spotlight                                    89.417722
# the-big-short                                90.123457
# dead-poets-society                           94.647013
# bridge-of-spies                              96.965211
# dunkirk                                     100.000000
# the-revenant                                100.000000

# %% [markdown]
# **Number of sentences by race and film**

# %%
double_word_group("sentences", "film", "race_simple").sort_values(
    by = "poc_percent",
    ascending = False
)
# Out:
#                                           total_sentences  white_percent  \
# film
# get-out                                              1330      50.902256
# driving-miss-daisy                                   1520      64.210526
# the-martian                                          1507      75.779695
# field-of-dreams                                      1299      84.064665
# the-shape-of-water                                   1347      85.077951
# mad-max                                               694      90.778098
# room                                                 1414      93.493635
# three-billboards-outside-ebbing-missouri             1195      93.640167
# lady-bird                                            1148      95.731707
# the-big-short                                        1782      96.015713
# darkest-hour                                         1077      97.493036
# born-on-the-fourth-of-july                            620      97.580645
# the-post                                             1528      99.149215
# dunkirk                                               446     100.000000
# dead-poets-society                                   1289     100.000000
# bridge-of-spies                                      1351     100.000000
# my-left-foot                                          980     100.000000
# phantom-thread                                        783     100.000000
# spotlight                                            1975     100.000000
# call-me-by-your-name                                 1048     100.000000
# the-revenant                                          549     100.000000
# brooklyn                                             1469     100.000000
#
#                                           poc_percent
# film
# get-out                                     49.097744
# driving-miss-daisy                          35.789474
# the-martian                                 24.220305
# field-of-dreams                             15.935335
# the-shape-of-water                          14.922049
# mad-max                                      9.221902
# room                                         6.506365
# three-billboards-outside-ebbing-missouri     6.359833
# lady-bird                                    4.268293
# the-big-short                                3.984287
# darkest-hour                                 2.506964
# born-on-the-fourth-of-july                   2.419355
# the-post                                     0.850785
# dunkirk                                      0.000000
# dead-poets-society                           0.000000
# bridge-of-spies                              0.000000
# my-left-foot                                 0.000000
# phantom-thread                               0.000000
# spotlight                                    0.000000
# call-me-by-your-name                         0.000000
# the-revenant                                 0.000000
# brooklyn                                     0.000000

# %% [markdown]
# ** Number of words by race and film **

# %%
double_word_group("words", "film", "race_simple").sort_values(
    by = "poc_percent",
    ascending = False
)
# Out:
#                                           total_words  white_percent  \
# film
# get-out                                          7094      53.354948
# driving-miss-daisy                               9675      63.503876
# the-martian                                     10550      75.459716
# the-shape-of-water                               8036      83.586361
# field-of-dreams                                  8933      84.674801
# mad-max                                          3130      89.776358
# three-billboards-outside-ebbing-missouri         9480      91.751055
# room                                             8373      92.643019
# born-on-the-fourth-of-july                       5151      95.961949
# the-big-short                                   13241      96.110566
# lady-bird                                        7664      96.189979
# darkest-hour                                     8034      98.170276
# the-post                                        11135      98.428379
# dunkirk                                          2353     100.000000
# dead-poets-society                               5217     100.000000
# bridge-of-spies                                  9915     100.000000
# my-left-foot                                     4749     100.000000
# phantom-thread                                   5541     100.000000
# spotlight                                       13113     100.000000
# call-me-by-your-name                             6673     100.000000
# the-revenant                                     4005     100.000000
# brooklyn                                        10591     100.000000
#
#                                           poc_percent
# film
# get-out                                     46.645052
# driving-miss-daisy                          36.496124
# the-martian                                 24.540284
# the-shape-of-water                          16.413639
# field-of-dreams                             15.325199
# mad-max                                     10.223642
# three-billboards-outside-ebbing-missouri     8.248945
# room                                         7.356981
# born-on-the-fourth-of-july                   4.038051
# the-big-short                                3.889434
# lady-bird                                    3.810021
# darkest-hour                                 1.829724
# the-post                                     1.571621
# dunkirk                                      0.000000
# dead-poets-society                           0.000000
# bridge-of-spies                              0.000000
# my-left-foot                                 0.000000
# phantom-thread                               0.000000
# spotlight                                    0.000000
# call-me-by-your-name                         0.000000
# the-revenant                                 0.000000
# brooklyn                                     0.000000

# %% [markdown]
# ---
#
# ---
#
# ---
